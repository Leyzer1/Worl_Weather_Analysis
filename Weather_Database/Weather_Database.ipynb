# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 736

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | zhuhai
# Processing Record 2 of the Set 1 | la ronge
# Processing Record 3 of the Set 1 | port blair
# Processing Record 4 of the Set 1 | ushuaia
# Processing Record 5 of the Set 1 | dingle
# Processing Record 6 of the Set 1 | yellowknife
# Processing Record 7 of the Set 1 | naifaru
# Processing Record 8 of the Set 1 | ukiah
# Processing Record 9 of the Set 1 | yar-sale
# Processing Record 10 of the Set 1 | chuy
# Processing Record 11 of the Set 1 | qaanaaq
# Processing Record 12 of the Set 1 | chokurdakh
# Processing Record 13 of the Set 1 | bredasdorp
# Processing Record 14 of the Set 1 | lac du bonnet
# Processing Record 15 of the Set 1 | albany
# Processing Record 16 of the Set 1 | mataura
# Processing Record 17 of the Set 1 | khandyga
# Processing Record 18 of the Set 1 | clarence town
# Processing Record 19 of the Set 1 | barcelos
# Processing Record 20 of the Set 1 | hamilton
# Processing Record 21 of the Set 1 | eskasem
# City not found. Skipping...
# Processing Record 22 of the Set 1 | illoqqortoormiut
# Processing Record 23 of the Set 1 | port elizabeth
# Processing Record 24 of the Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of the Set 1 | atuona
# Processing Record 26 of the Set 1 | busselton
# Processing Record 27 of the Set 1 | sakakah
# Processing Record 28 of the Set 1 | mar del plata
# Processing Record 29 of the Set 1 | boa vista
# Processing Record 30 of the Set 1 | bethel
# Processing Record 31 of the Set 1 | upernavik
# Processing Record 32 of the Set 1 | anadyr
# Processing Record 33 of the Set 1 | camacha
# Processing Record 34 of the Set 1 | yichang
# Processing Record 35 of the Set 1 | waingapu
# Processing Record 36 of the Set 1 | nur
# Processing Record 37 of the Set 1 | new norfolk
# Processing Record 38 of the Set 1 | xam nua
# Processing Record 39 of the Set 1 | wanning
# Processing Record 40 of the Set 1 | port alfred
# Processing Record 41 of the Set 1 | brigantine
# Processing Record 42 of the Set 1 | khonuu
# Processing Record 43 of the Set 1 | cidreira
# Processing Record 44 of the Set 1 | lasa
# Processing Record 45 of the Set 1 | san patricio
# Processing Record 46 of the Set 1 | qafsah
# City not found. Skipping...
# Processing Record 47 of the Set 1 | cape town
# Processing Record 48 of the Set 1 | kirakira
# Processing Record 49 of the Set 1 | saint-philippe
# Processing Record 50 of the Set 1 | skrunda
# Processing Record 1 of the Set 2 | matara
# Processing Record 2 of the Set 2 | minot
# Processing Record 3 of the Set 2 | cairns
# Processing Record 4 of the Set 2 | salalah
# Processing Record 5 of the Set 2 | carnarvon
# Processing Record 6 of the Set 2 | rikitea
# Processing Record 7 of the Set 2 | jambi
# Processing Record 8 of the Set 2 | ca mau
# Processing Record 9 of the Set 2 | hermanus
# Processing Record 10 of the Set 2 | dubrovka
# Processing Record 11 of the Set 2 | rabo de peixe
# Processing Record 12 of the Set 2 | vaini
# Processing Record 13 of the Set 2 | gat
# Processing Record 14 of the Set 2 | paramirim
# Processing Record 15 of the Set 2 | chabahar
# Processing Record 16 of the Set 2 | east london
# Processing Record 17 of the Set 2 | kiama
# Processing Record 18 of the Set 2 | puerto ayora
# Processing Record 19 of the Set 2 | yuanping
# Processing Record 20 of the Set 2 | oneida
# Processing Record 21 of the Set 2 | bagotville
# Processing Record 22 of the Set 2 | barrow
# Processing Record 23 of the Set 2 | aksarka
# Processing Record 24 of the Set 2 | villamontes
# Processing Record 25 of the Set 2 | hobart
# Processing Record 26 of the Set 2 | bambous virieux
# City not found. Skipping...
# Processing Record 27 of the Set 2 | katsuura
# Processing Record 28 of the Set 2 | nikolskoye
# Processing Record 29 of the Set 2 | punta arenas
# Processing Record 30 of the Set 2 | norsup
# Processing Record 31 of the Set 2 | kavieng
# Processing Record 32 of the Set 2 | mayumba
# Processing Record 33 of the Set 2 | prokopyevsk
# Processing Record 34 of the Set 2 | altay
# Processing Record 35 of the Set 2 | coihaique
# Processing Record 36 of the Set 2 | bonthe
# Processing Record 37 of the Set 2 | cascais
# Processing Record 38 of the Set 2 | mitsamiouli
# Processing Record 39 of the Set 2 | kahului
# Processing Record 40 of the Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of the Set 2 | eureka
# Processing Record 43 of the Set 2 | winneba
# Processing Record 44 of the Set 2 | los llanos de aridane
# Processing Record 45 of the Set 2 | kapaa
# Processing Record 46 of the Set 2 | balkanabat
# Processing Record 47 of the Set 2 | pokhara
# Processing Record 48 of the Set 2 | ingraj bazar
# Processing Record 49 of the Set 2 | hualmay
# Processing Record 50 of the Set 2 | saint-louis
# Processing Record 1 of the Set 3 | georgetown
# Processing Record 2 of the Set 3 | longyearbyen
# Processing Record 3 of the Set 3 | tiznit
# Processing Record 4 of the Set 3 | road town
# Processing Record 5 of the Set 3 | dikson
# Processing Record 6 of the Set 3 | hilo
# Processing Record 7 of the Set 3 | bluff
# Processing Record 8 of the Set 3 | lompoc
# Processing Record 9 of the Set 3 | kruisfontein
# Processing Record 10 of the Set 3 | faanui
# Processing Record 11 of the Set 3 | resistencia
# Processing Record 12 of the Set 3 | jamestown
# Processing Record 13 of the Set 3 | oranjemund
# Processing Record 14 of the Set 3 | antalya
# Processing Record 15 of the Set 3 | tuktoyaktuk
# Processing Record 16 of the Set 3 | buala
# Processing Record 17 of the Set 3 | kon tum
# Processing Record 18 of the Set 3 | khatanga
# Processing Record 19 of the Set 3 | ugoofaaru
# Processing Record 20 of the Set 3 | troitskoye
# Processing Record 21 of the Set 3 | srednekolymsk
# Processing Record 22 of the Set 3 | souillac
# City not found. Skipping...
# Processing Record 23 of the Set 3 | cherskiy
# Processing Record 24 of the Set 3 | byron bay
# Processing Record 25 of the Set 3 | hithadhoo
# Processing Record 26 of the Set 3 | ozinki
# Processing Record 27 of the Set 3 | raisen
# Processing Record 28 of the Set 3 | pombal
# Processing Record 29 of the Set 3 | viedma
# Processing Record 30 of the Set 3 | bengkulu
# Processing Record 31 of the Set 3 | saint george
# Processing Record 32 of the Set 3 | galiwinku
# Processing Record 33 of the Set 3 | codrington
# Processing Record 34 of the Set 3 | ramgarh
# Processing Record 35 of the Set 3 | yeppoon
# Processing Record 36 of the Set 3 | bharatpur
# Processing Record 37 of the Set 3 | puerto del rosario
# Processing Record 38 of the Set 3 | kanniyakumari
# Processing Record 39 of the Set 3 | pinawa
# Processing Record 40 of the Set 3 | touros
# Processing Record 41 of the Set 3 | cabo san lucas
# Processing Record 42 of the Set 3 | eenhana
# Processing Record 43 of the Set 3 | port moresby
# Processing Record 44 of the Set 3 | meulaboh
# Processing Record 45 of the Set 3 | ye
# City not found. Skipping...
# Processing Record 46 of the Set 3 | ancud
# Processing Record 47 of the Set 3 | hengshui
# Processing Record 48 of the Set 3 | oistins
# Processing Record 49 of the Set 3 | padang
# Processing Record 50 of the Set 3 | gouyave
# Processing Record 1 of the Set 4 | kavaratti
# Processing Record 2 of the Set 4 | cabadiangan
# Processing Record 3 of the Set 4 | ribeira grande
# Processing Record 4 of the Set 4 | bardiyah
# Processing Record 5 of the Set 4 | murgab
# Processing Record 6 of the Set 4 | alofi
# Processing Record 7 of the Set 4 | ghanzi
# Processing Record 8 of the Set 4 | belushya guba
# Processing Record 9 of the Set 4 | urengoy
# Processing Record 10 of the Set 4 | kirov
# Processing Record 11 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 12 of the Set 4 | mys shmidta
# Processing Record 13 of the Set 4 | henderson
# Processing Record 14 of the Set 4 | tuatapere
# Processing Record 15 of the Set 4 | port hedland
# Processing Record 16 of the Set 4 | samarai
# Processing Record 17 of the Set 4 | ambanja
# City not found. Skipping...
# Processing Record 18 of the Set 4 | tasiilaq
# Processing Record 19 of the Set 4 | sao filipe
# Processing Record 20 of the Set 4 | sitka
# Processing Record 21 of the Set 4 | barentsburg
# Processing Record 22 of the Set 4 | kaitangata
# Processing Record 23 of the Set 4 | saint-augustin
# Processing Record 24 of the Set 4 | palabuhanratu
# Processing Record 25 of the Set 4 | amderma
# Processing Record 26 of the Set 4 | cayenne
# Processing Record 27 of the Set 4 | sao miguel do araguaia
# Processing Record 28 of the Set 4 | mackay
# Processing Record 29 of the Set 4 | soars
# Processing Record 30 of the Set 4 | sentyabrskiy
# Processing Record 31 of the Set 4 | bo
# City not found. Skipping...
# Processing Record 32 of the Set 4 | ixtlahuacan del rio
# Processing Record 33 of the Set 4 | lata
# Processing Record 34 of the Set 4 | nguru
# Processing Record 35 of the Set 4 | burica
# City not found. Skipping...
# Processing Record 36 of the Set 4 | ostrovnoy
# Processing Record 37 of the Set 4 | ningxiang
# Processing Record 38 of the Set 4 | rio gallegos
# Processing Record 39 of the Set 4 | bilma
# Processing Record 40 of the Set 4 | puerto el triunfo
# Processing Record 41 of the Set 4 | appleton
# Processing Record 42 of the Set 4 | burpengary
# Processing Record 43 of the Set 4 | avarua
# Processing Record 44 of the Set 4 | margate
# Processing Record 45 of the Set 4 | saryg-sep
# Processing Record 46 of the Set 4 | veraval
# Processing Record 47 of the Set 4 | omsukchan
# Processing Record 48 of the Set 4 | mahebourg
# City not found. Skipping...
# Processing Record 49 of the Set 4 | lagoa
# Processing Record 50 of the Set 4 | khani
# Processing Record 1 of the Set 5 | victoria
# Processing Record 2 of the Set 5 | buraydah
# Processing Record 3 of the Set 5 | airai
# Processing Record 4 of the Set 5 | zlobin
# Processing Record 5 of the Set 5 | qui nhon
# Processing Record 6 of the Set 5 | bjerkvik
# City not found. Skipping...
# Processing Record 7 of the Set 5 | beringovskiy
# Processing Record 8 of the Set 5 | zolotinka
# Processing Record 9 of the Set 5 | ulagan
# Processing Record 10 of the Set 5 | namatanai
# Processing Record 11 of the Set 5 | iqaluit
# Processing Record 12 of the Set 5 | east retford
# Processing Record 13 of the Set 5 | lithgow
# Processing Record 14 of the Set 5 | attawapiskat
# Processing Record 15 of the Set 5 | deputatskiy
# Processing Record 16 of the Set 5 | yulara
# Processing Record 17 of the Set 5 | antalaha
# City not found. Skipping...
# Processing Record 18 of the Set 5 | lebu
# Processing Record 19 of the Set 5 | roseburg
# Processing Record 20 of the Set 5 | baishishan
# Processing Record 21 of the Set 5 | norman wells
# Processing Record 22 of the Set 5 | marrakesh
# Processing Record 23 of the Set 5 | gunnedah
# Processing Record 24 of the Set 5 | bargal
# City not found. Skipping...
# Processing Record 25 of the Set 5 | ahipara
# Processing Record 26 of the Set 5 | butaritari
# Processing Record 27 of the Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 28 of the Set 5 | vao
# Processing Record 29 of the Set 5 | cap malheureux
# City not found. Skipping...
# Processing Record 30 of the Set 5 | nara
# Processing Record 31 of the Set 5 | naze
# Processing Record 32 of the Set 5 | vila franca do campo
# Processing Record 33 of the Set 5 | san policarpo
# Processing Record 34 of the Set 5 | ouesso
# Processing Record 35 of the Set 5 | marsaxlokk
# Processing Record 36 of the Set 5 | doetinchem
# Processing Record 37 of the Set 5 | yerbogachen
# Processing Record 38 of the Set 5 | moerai
# Processing Record 39 of the Set 5 | brownsville
# Processing Record 40 of the Set 5 | ijaki
# Processing Record 41 of the Set 5 | khasan
# Processing Record 42 of the Set 5 | tiksi
# Processing Record 43 of the Set 5 | barra do bugres
# Processing Record 44 of the Set 5 | pennagaram
# Processing Record 45 of the Set 5 | riyadh
# Processing Record 46 of the Set 5 | kulhudhuffushi
# Processing Record 47 of the Set 5 | shenjiamen
# Processing Record 48 of the Set 5 | te anau
# Processing Record 49 of the Set 5 | xining
# Processing Record 50 of the Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of the Set 6 | victor harbor
# Processing Record 2 of the Set 6 | sao felix do xingu
# Processing Record 3 of the Set 6 | neuquen
# Processing Record 4 of the Set 6 | sinnamary
# Processing Record 5 of the Set 6 | arraial do cabo
# Processing Record 6 of the Set 6 | rosignol
# Processing Record 7 of the Set 6 | castro
# Processing Record 8 of the Set 6 | severo-kurilsk
# Processing Record 9 of the Set 6 | union city
# Processing Record 10 of the Set 6 | bauchi
# Processing Record 11 of the Set 6 | ormara
# Processing Record 12 of the Set 6 | basco
# Processing Record 13 of the Set 6 | santo amaro da imperatriz
# Processing Record 14 of the Set 6 | lethem
# Processing Record 15 of the Set 6 | opuwo
# Processing Record 16 of the Set 6 | yabelo
# Processing Record 17 of the Set 6 | provideniya
# Processing Record 18 of the Set 6 | stornoway
# Processing Record 19 of the Set 6 | half moon bay
# Processing Record 20 of the Set 6 | korla
# Processing Record 21 of the Set 6 | saldanha
# Processing Record 22 of the Set 6 | pietersburg
# Processing Record 23 of the Set 6 | hasaki
# Processing Record 24 of the Set 6 | mordovo
# Processing Record 25 of the Set 6 | evensk
# Processing Record 26 of the Set 6 | great yarmouth
# Processing Record 27 of the Set 6 | virginia beach
# Processing Record 28 of the Set 6 | xiuyan
# Processing Record 29 of the Set 6 | ust-nera
# Processing Record 30 of the Set 6 | ulaanbaatar
# Processing Record 31 of the Set 6 | praia da vitoria
# Processing Record 32 of the Set 6 | pevek
# Processing Record 33 of the Set 6 | jishu
# Processing Record 34 of the Set 6 | teupasenti
# Processing Record 35 of the Set 6 | latung
# Processing Record 36 of the Set 6 | bosaso
# City not found. Skipping...
# Processing Record 37 of the Set 6 | dalbandin
# Processing Record 38 of the Set 6 | chara
# Processing Record 39 of the Set 6 | honningsvag
# City not found. Skipping...
# Processing Record 40 of the Set 6 | radcliff
# Processing Record 41 of the Set 6 | nanortalik
# Processing Record 42 of the Set 6 | boyolangu
# Processing Record 43 of the Set 6 | khor
# Processing Record 44 of the Set 6 | luderitz
# Processing Record 45 of the Set 6 | port lincoln
# Processing Record 46 of the Set 6 | lorengau
# Processing Record 47 of the Set 6 | esperance
# Processing Record 48 of the Set 6 | nizhneyansk
# Processing Record 49 of the Set 6 | sidi ali
# Processing Record 50 of the Set 6 | mukhen
# Processing Record 1 of the Set 7 | khlung
# Processing Record 2 of the Set 7 | sterling
# Processing Record 3 of the Set 7 | puerto escondido
# Processing Record 4 of the Set 7 | yokadouma
# Processing Record 5 of the Set 7 | mangan
# Processing Record 6 of the Set 7 | thompson
# Processing Record 7 of the Set 7 | lima
# Processing Record 8 of the Set 7 | saurimo
# Processing Record 9 of the Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 10 of the Set 7 | vestmannaeyjar
# Processing Record 11 of the Set 7 | kodiak
# Processing Record 12 of the Set 7 | rungata
# Processing Record 13 of the Set 7 | kununurra
# Processing Record 14 of the Set 7 | elverum
# City not found. Skipping...
# Processing Record 15 of the Set 7 | shingu
# Processing Record 16 of the Set 7 | klyuchi
# Processing Record 17 of the Set 7 | loukhi
# Processing Record 18 of the Set 7 | pacific grove
# Processing Record 19 of the Set 7 | waipawa
# Processing Record 20 of the Set 7 | tarudant
# Processing Record 21 of the Set 7 | banda aceh
# Processing Record 22 of the Set 7 | namibe
# Processing Record 23 of the Set 7 | kupang
# Processing Record 24 of the Set 7 | fuerte olimpo
# Processing Record 25 of the Set 7 | santa ana
# Processing Record 26 of the Set 7 | ilulissat
# Processing Record 27 of the Set 7 | aden
# Processing Record 28 of the Set 7 | kedrovyy
# Processing Record 29 of the Set 7 | palmer
# Processing Record 30 of the Set 7 | sandakan
# Processing Record 31 of the Set 7 | broome
# Processing Record 32 of the Set 7 | coquimbo
# Processing Record 33 of the Set 7 | bolungarvik
# Processing Record 34 of the Set 7 | tjome
# City not found. Skipping...
# Processing Record 35 of the Set 7 | grand baie
# Processing Record 36 of the Set 7 | noumea
# Processing Record 37 of the Set 7 | portland
# Processing Record 38 of the Set 7 | grand gaube
# Processing Record 39 of the Set 7 | nagato
# Processing Record 40 of the Set 7 | itaqui
# Processing Record 41 of the Set 7 | gulbarga
# Processing Record 42 of the Set 7 | gimli
# Processing Record 43 of the Set 7 | henties bay
# Processing Record 44 of the Set 7 | tabou
# Processing Record 45 of the Set 7 | manggar
# Processing Record 46 of the Set 7 | ingham
# Processing Record 47 of the Set 7 | mosquera
# Processing Record 48 of the Set 7 | pochutla
# Processing Record 49 of the Set 7 | mayskiy
# Processing Record 50 of the Set 7 | suntar
# Processing Record 1 of the Set 8 | mamallapuram
# Processing Record 2 of the Set 8 | iranshahr
# Processing Record 3 of the Set 8 | copiapo
# Processing Record 4 of the Set 8 | guangyuan
# Processing Record 5 of the Set 8 | nantucket
# Processing Record 6 of the Set 8 | clyde river
# Processing Record 7 of the Set 8 | colombo
# Processing Record 8 of the Set 8 | sri aman
# Processing Record 9 of the Set 8 | shelburne
# Processing Record 10 of the Set 8 | saleaula
# City not found. Skipping...
# Processing Record 11 of the Set 8 | goderich
# Processing Record 12 of the Set 8 | brynmawr
# Processing Record 13 of the Set 8 | tibati
# Processing Record 14 of the Set 8 | daru
# Processing Record 15 of the Set 8 | nguiu
# Processing Record 16 of the Set 8 | sinjar
# Processing Record 17 of the Set 8 | peniche
# Processing Record 18 of the Set 8 | luwingu
# Processing Record 19 of the Set 8 | sungai besar
# Processing Record 20 of the Set 8 | yirol
# City not found. Skipping...
# Processing Record 21 of the Set 8 | zalantun
# Processing Record 22 of the Set 8 | ponta do sol
# Processing Record 23 of the Set 8 | bartlett
# Processing Record 24 of the Set 8 | panjakent
# Processing Record 25 of the Set 8 | hirara
# Processing Record 26 of the Set 8 | oussouye
# Processing Record 27 of the Set 8 | tendukheda
# Processing Record 28 of the Set 8 | amapa
# Processing Record 29 of the Set 8 | port hardy
# Processing Record 30 of the Set 8 | thunder bay
# Processing Record 31 of the Set 8 | khorramshahr
# Processing Record 32 of the Set 8 | richards bay
# Processing Record 33 of the Set 8 | ketchikan
# Processing Record 34 of the Set 8 | acarau
# Processing Record 35 of the Set 8 | cagayan de tawi-tawi
# Processing Record 36 of the Set 8 | taoudenni
# Processing Record 37 of the Set 8 | saint-georges
# Processing Record 38 of the Set 8 | blonduos
# Processing Record 39 of the Set 8 | kamenka
# Processing Record 40 of the Set 8 | okha
# Processing Record 41 of the Set 8 | straumen
# City not found. Skipping...
# Processing Record 42 of the Set 8 | pinotepa nacional
# Processing Record 43 of the Set 8 | saskylakh
# Processing Record 44 of the Set 8 | lolua
# City not found. Skipping...
# Processing Record 45 of the Set 8 | ahuimanu
# Processing Record 46 of the Set 8 | mount gambier
# Processing Record 47 of the Set 8 | haines junction
# Processing Record 48 of the Set 8 | aklavik
# Processing Record 49 of the Set 8 | eyl
# City not found. Skipping...
# Processing Record 50 of the Set 8 | auki
# Processing Record 1 of the Set 9 | nisia floresta
# Processing Record 2 of the Set 9 | khabary
# Processing Record 3 of the Set 9 | saint-joseph
# Processing Record 4 of the Set 9 | soanierana ivongo
# Processing Record 5 of the Set 9 | wahpeton
# Processing Record 6 of the Set 9 | acapulco
# Processing Record 7 of the Set 9 | salta
# Processing Record 8 of the Set 9 | cabedelo
# Processing Record 9 of the Set 9 | mogadishu
# City not found. Skipping...
# Processing Record 10 of the Set 9 | rorvik
# City not found. Skipping...
# Processing Record 11 of the Set 9 | makakilo city
# Processing Record 12 of the Set 9 | hervey bay
# Processing Record 13 of the Set 9 | ruatoria
# Processing Record 14 of the Set 9 | konibodom
# Processing Record 15 of the Set 9 | mutsamudu
# Processing Record 16 of the Set 9 | homer
# Processing Record 17 of the Set 9 | belmonte
# Processing Record 18 of the Set 9 | santa rosa
# Processing Record 19 of the Set 9 | komsomolskiy
# Processing Record 20 of the Set 9 | hami
# Processing Record 21 of the Set 9 | novobeysugskaya
# Processing Record 22 of the Set 9 | ust-omchug
# Processing Record 23 of the Set 9 | caravelas
# Processing Record 24 of the Set 9 | asau
# City not found. Skipping...
# Processing Record 25 of the Set 9 | ternate
# Processing Record 26 of the Set 9 | mezen
# Processing Record 27 of the Set 9 | surt
# Processing Record 28 of the Set 9 | torbay
# Processing Record 29 of the Set 9 | wagga wagga
# Processing Record 30 of the Set 9 | makkaveyevo
# Processing Record 31 of the Set 9 | tsienyane
# Processing Record 32 of the Set 9 | andenes
# City not found. Skipping...
# Processing Record 33 of the Set 9 | leshukonskoye
# Processing Record 34 of the Set 9 | bambanglipuro
# Processing Record 35 of the Set 9 | volterra
# Processing Record 36 of the Set 9 | tromso
# City not found. Skipping...
# Processing Record 37 of the Set 9 | dolgorukovo
# Processing Record 38 of the Set 9 | snezhnogorsk
# Processing Record 39 of the Set 9 | boguchany
# Processing Record 40 of the Set 9 | hendijan
# Processing Record 41 of the Set 9 | belaya gora
# Processing Record 42 of the Set 9 | roma
# Processing Record 43 of the Set 9 | lewiston
# Processing Record 44 of the Set 9 | millau
# Processing Record 45 of the Set 9 | valparaiso
# Processing Record 46 of the Set 9 | sakaiminato
# Processing Record 47 of the Set 9 | sangar
# Processing Record 48 of the Set 9 | north platte
# Processing Record 49 of the Set 9 | karamea
# Processing Record 50 of the Set 9 | talara
# Processing Record 1 of the Set 10 | camana
# Processing Record 2 of the Set 10 | yining
# Processing Record 3 of the Set 10 | halmstad
# Processing Record 4 of the Set 10 | abnub
# Processing Record 5 of the Set 10 | malanje
# Processing Record 6 of the Set 10 | burnie
# Processing Record 7 of the Set 10 | san jeronimo
# Processing Record 8 of the Set 10 | taman
# Processing Record 9 of the Set 10 | moron
# Processing Record 10 of the Set 10 | biak
# Processing Record 11 of the Set 10 | lipin bor
# Processing Record 12 of the Set 10 | armstrong
# Processing Record 13 of the Set 10 | uzunkopru
# Processing Record 14 of the Set 10 | brae
# Processing Record 15 of the Set 10 | lixourion
# Processing Record 16 of the Set 10 | bereda
# City not found. Skipping...
# Processing Record 17 of the Set 10 | nelson bay
# Processing Record 18 of the Set 10 | vardo
# City not found. Skipping...
# Processing Record 19 of the Set 10 | teguise
# Processing Record 20 of the Set 10 | vanimo
# Processing Record 21 of the Set 10 | sorland
# Processing Record 22 of the Set 10 | chibombo
# Processing Record 23 of the Set 10 | tsiroanomandidy
# Processing Record 24 of the Set 10 | nyurba
# Processing Record 25 of the Set 10 | tretten
# Processing Record 26 of the Set 10 | kungurtug
# Processing Record 27 of the Set 10 | kolokani
# Processing Record 28 of the Set 10 | mocuba
# Processing Record 29 of the Set 10 | matamoros
# Processing Record 30 of the Set 10 | hambantota
# Processing Record 31 of the Set 10 | necochea
# Processing Record 32 of the Set 10 | mount pleasant
# Processing Record 33 of the Set 10 | petropavlovsk-kamchatskiy
# Processing Record 34 of the Set 10 | anta
# Processing Record 35 of the Set 10 | hamilton
# Processing Record 36 of the Set 10 | mwinilunga
# Processing Record 37 of the Set 10 | hatillo
# Processing Record 38 of the Set 10 | danielskuil
# Processing Record 39 of the Set 10 | abu samrah
# Processing Record 40 of the Set 10 | pinyug
# Processing Record 41 of the Set 10 | benjamin hill
# Processing Record 42 of the Set 10 | kirillov
# Processing Record 43 of the Set 10 | constitucion
# Processing Record 44 of the Set 10 | calvinia
# Processing Record 45 of the Set 10 | flin flon
# Processing Record 46 of the Set 10 | nizwa
# Processing Record 47 of the Set 10 | galle
# Processing Record 48 of the Set 10 | kailua
# Processing Record 49 of the Set 10 | fairbanks
# Processing Record 50 of the Set 10 | salinas
# Processing Record 1 of the Set 11 | nouadhibou
# Processing Record 2 of the Set 11 | rawson
# Processing Record 3 of the Set 11 | inhambane
# Processing Record 4 of the Set 11 | thano bula khan
# Processing Record 5 of the Set 11 | baruun-urt
# Processing Record 6 of the Set 11 | chepo
# Processing Record 7 of the Set 11 | raul soares
# Processing Record 8 of the Set 11 | fortuna
# Processing Record 9 of the Set 11 | tautira
# Processing Record 10 of the Set 11 | atambua
# Processing Record 11 of the Set 11 | sug-aksy
# Processing Record 12 of the Set 11 | mareeba
# Processing Record 13 of the Set 11 | magadan
# Processing Record 14 of the Set 11 | santa maria
# Processing Record 15 of the Set 11 | harer
# Processing Record 16 of the Set 11 | grants pass
# Processing Record 17 of the Set 11 | svetlogorsk
# Processing Record 18 of the Set 11 | kenai
# Processing Record 19 of the Set 11 | fukuma
# Processing Record 20 of the Set 11 | merida
# Processing Record 21 of the Set 11 | zhigansk
# Processing Record 22 of the Set 11 | siva
# Processing Record 23 of the Set 11 | sainte-marie
# Processing Record 24 of the Set 11 | fereydun kenar
# Processing Record 25 of the Set 11 | berlevag
# Processing Record 26 of the Set 11 | shkotovo-22
# Processing Record 27 of the Set 11 | inverell
# Processing Record 28 of the Set 11 | aykhal
# Processing Record 29 of the Set 11 | plouzane
# Processing Record 30 of the Set 11 | antigonish
# Processing Record 31 of the Set 11 | sao jose da coroa grande
# Processing Record 32 of the Set 11 | rundu
# Processing Record 33 of the Set 11 | chute-aux-outardes
# Processing Record 34 of the Set 11 | hihifo
# Processing Record 35 of the Set 11 | kyzyl-suu
# Processing Record 36 of the Set 11 | staraya russa
# Processing Record 37 of the Set 11 | tocopilla
# Processing Record 38 of the Set 11 | san carlos de bariloche
# Processing Record 39 of the Set 11 | aleksandrov gay
# Processing Record 40 of the Set 11 | wa
# Processing Record 41 of the Set 11 | tumannyy
# Processing Record 42 of the Set 11 | marcona
# Processing Record 43 of the Set 11 | ikole
# Processing Record 44 of the Set 11 | pangnirtung
# Processing Record 45 of the Set 11 | kencong
# Processing Record 46 of the Set 11 | tefe
# Processing Record 47 of the Set 11 | hay river
# Processing Record 48 of the Set 11 | shaowu
# Processing Record 49 of the Set 11 | gayeri
# Processing Record 50 of the Set 11 | shihezi
# Processing Record 1 of the Set 12 | faya
# Processing Record 2 of the Set 12 | tabiauea
# Processing Record 3 of the Set 12 | falealupo
# City not found. Skipping...
# Processing Record 4 of the Set 12 | klaksvik
# Processing Record 5 of the Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of the Set 12 | kemijarvi
# Processing Record 7 of the Set 12 | tres arroyos
# Processing Record 8 of the Set 12 | lachi
# Processing Record 9 of the Set 12 | vila velha
# Processing Record 10 of the Set 12 | poso
# Processing Record 11 of the Set 12 | olafsvik
# Processing Record 12 of the Set 12 | santa catarina de tepehuanes
# Processing Record 13 of the Set 12 | lavrentiya
# Processing Record 14 of the Set 12 | halalo
# City not found. Skipping...
# Processing Record 15 of the Set 12 | bow island
# Processing Record 16 of the Set 12 | loa janan
# Processing Record 17 of the Set 12 | flinders
# Processing Record 18 of the Set 12 | gboko
# Processing Record 19 of the Set 12 | husavik
# Processing Record 20 of the Set 12 | adrar
# Processing Record 21 of the Set 12 | qesarya
# Processing Record 22 of the Set 12 | karaul
# Processing Record 23 of the Set 12 | regina
# Processing Record 24 of the Set 12 | yelizovo
# Processing Record 25 of the Set 12 | kitakami
# Processing Record 26 of the Set 12 | bonavista
# Processing Record 27 of the Set 12 | taksimo
# Processing Record 28 of the Set 12 | sao joao da barra
# Processing Record 29 of the Set 12 | mbini
# Processing Record 30 of the Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 31 of the Set 12 | olinda
# Processing Record 32 of the Set 12 | creston
# Processing Record 33 of the Set 12 | matam
# Processing Record 34 of the Set 12 | garm
# Processing Record 35 of the Set 12 | mount isa
# Processing Record 36 of the Set 12 | puno
# Processing Record 37 of the Set 12 | san quintin
# Processing Record 38 of the Set 12 | beirut
# Processing Record 39 of the Set 12 | charters towers
# Processing Record 40 of the Set 12 | vostok
# Processing Record 41 of the Set 12 | montijo
# Processing Record 42 of the Set 12 | tayshet
# Processing Record 43 of the Set 12 | sompeta
# Processing Record 44 of the Set 12 | canberra
# Processing Record 45 of the Set 12 | kalabo
# Processing Record 46 of the Set 12 | dongfeng
# Processing Record 47 of the Set 12 | fort nelson
# Processing Record 48 of the Set 12 | narrabri
# Processing Record 49 of the Set 12 | narsaq
# Processing Record 50 of the Set 12 | maragogi
# Processing Record 1 of the Set 13 | gurgan
# City not found. Skipping...
# Processing Record 2 of the Set 13 | sobolevo
# Processing Record 3 of the Set 13 | kawalu
# Processing Record 4 of the Set 13 | dukat
# Processing Record 5 of the Set 13 | cody
# Processing Record 6 of the Set 13 | pechora
# Processing Record 7 of the Set 13 | arlit
# Processing Record 8 of the Set 13 | jieshi
# Processing Record 9 of the Set 13 | kenitra
# Processing Record 10 of the Set 13 | tuggurt
# Processing Record 11 of the Set 13 | jalu
# Processing Record 12 of the Set 13 | majene
# Processing Record 13 of the Set 13 | geraldton
# Processing Record 14 of the Set 13 | longview
# Processing Record 15 of the Set 13 | vagur
# Processing Record 16 of the Set 13 | chicama
# Processing Record 17 of the Set 13 | ballina
# Processing Record 18 of the Set 13 | montanha
# Processing Record 19 of the Set 13 | kegayli
# City not found. Skipping...
# Processing Record 20 of the Set 13 | batagay
# Processing Record 21 of the Set 13 | miloslavskoye
# Processing Record 22 of the Set 13 | zaysan
# City not found. Skipping...
# Processing Record 23 of the Set 13 | tezu
# Processing Record 24 of the Set 13 | najran
# Processing Record 25 of the Set 13 | merauke
# Processing Record 26 of the Set 13 | longjiang
# Processing Record 27 of the Set 13 | rolim de moura
# Processing Record 28 of the Set 13 | nome
# Processing Record 29 of the Set 13 | salamanca
# Processing Record 30 of the Set 13 | colac
# Processing Record 31 of the Set 13 | kuching
# Processing Record 32 of the Set 13 | san cristobal
# Processing Record 33 of the Set 13 | seybaplaya
# Processing Record 34 of the Set 13 | prykolotne
# Processing Record 35 of the Set 13 | dwarka
# Processing Record 36 of the Set 13 | verdun
# Processing Record 37 of the Set 13 | liuhe
# Processing Record 38 of the Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of the Set 13 | gamba
# Processing Record 40 of the Set 13 | burjuc
# Processing Record 41 of the Set 13 | emerald
# Processing Record 42 of the Set 13 | cilegon
# Processing Record 43 of the Set 13 | leningradskiy
# Processing Record 44 of the Set 13 | hobyo
# City not found. Skipping...
# Processing Record 45 of the Set 13 | broken hill
# Processing Record 46 of the Set 13 | amahai
# Processing Record 47 of the Set 13 | harper
# Processing Record 48 of the Set 13 | mahibadhoo
# Processing Record 49 of the Set 13 | payakumbuh
# Processing Record 50 of the Set 13 | teruel
# Processing Record 1 of the Set 14 | show low
# Processing Record 2 of the Set 14 | bandarbeyla
# City not found. Skipping...
# Processing Record 3 of the Set 14 | pisco
# Processing Record 4 of the Set 14 | progreso
# Processing Record 5 of the Set 14 | itatskiy
# Processing Record 6 of the Set 14 | labutta
# City not found. Skipping...
# Processing Record 7 of the Set 14 | tarhunah
# Processing Record 8 of the Set 14 | albury
# Processing Record 9 of the Set 14 | port macquarie
# Processing Record 10 of the Set 14 | burriana
# Processing Record 11 of the Set 14 | waitati
# Processing Record 12 of the Set 14 | lena
# Processing Record 13 of the Set 14 | tessalit
# Processing Record 14 of the Set 14 | nhulunbuy
# Processing Record 15 of the Set 14 | maniitsoq
# Processing Record 16 of the Set 14 | maceio
# Processing Record 17 of the Set 14 | kloulklubed
# Processing Record 18 of the Set 14 | wajima
# Processing Record 19 of the Set 14 | ortigueira
# Processing Record 20 of the Set 14 | tual
# Processing Record 21 of the Set 14 | shimoda
# Processing Record 22 of the Set 14 | solnechnyy
# Processing Record 23 of the Set 14 | marsh harbour
# Processing Record 24 of the Set 14 | hornepayne
# Processing Record 25 of the Set 14 | canutama
# Processing Record 26 of the Set 14 | slagelse
# Processing Record 27 of the Set 14 | annau
# Processing Record 28 of the Set 14 | yablochnyy
# Processing Record 29 of the Set 14 | san matias
# Processing Record 30 of the Set 14 | bullhead city
# Processing Record 31 of the Set 14 | moses lake
# Processing Record 32 of the Set 14 | lincoln
# Processing Record 33 of the Set 14 | mastic beach
# Processing Record 34 of the Set 14 | kelvington
# Processing Record 35 of the Set 14 | kuala krai
# Processing Record 36 of the Set 14 | krasnaya gora
# Processing Record 37 of the Set 14 | baykit
# Processing Record 38 of the Set 14 | diu
# Processing Record 39 of the Set 14 | zhangye
# Processing Record 40 of the Set 14 | gemena
# Processing Record 41 of the Set 14 | yaan
# Processing Record 42 of the Set 14 | port-gentil
# Processing Record 43 of the Set 14 | loikaw
# City not found. Skipping...
# Processing Record 44 of the Set 14 | tongchuan
# Processing Record 45 of the Set 14 | ponta delgada
# Processing Record 46 of the Set 14 | abu kamal
# Processing Record 47 of the Set 14 | laguna
# Processing Record 48 of the Set 14 | kholtoson
# Processing Record 49 of the Set 14 | dekar
# Processing Record 50 of the Set 14 | whitianga
# Processing Record 1 of the Set 15 | quixada
# Processing Record 2 of the Set 15 | san jose
# Processing Record 3 of the Set 15 | afmadu
# City not found. Skipping...
# Processing Record 4 of the Set 15 | anamur
# Processing Record 5 of the Set 15 | susuman
# Processing Record 6 of the Set 15 | tabuk
# Processing Record 7 of the Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of the Set 15 | eydhafushi
# Processing Record 9 of the Set 15 | palauig
# Processing Record 10 of the Set 15 | hewitt
# Processing Record 11 of the Set 15 | shache
# Processing Record 12 of the Set 15 | hlukhiv
# Processing Record 13 of the Set 15 | ust-kuyga
# Processing Record 14 of the Set 15 | fuxin
# Processing Record 15 of the Set 15 | rurrenabaque
# Processing Record 16 of the Set 15 | plettenberg bay
# Processing Record 17 of the Set 15 | sioux lookout
# Processing Record 18 of the Set 15 | piuma
# Processing Record 19 of the Set 15 | kamenskoye
# Processing Record 20 of the Set 15 | nyrob
# Processing Record 21 of the Set 15 | chulym
# Processing Record 22 of the Set 15 | luganville
# Processing Record 23 of the Set 15 | anahuac
# Processing Record 24 of the Set 15 | santa vitoria do palmar
# Processing Record 25 of the Set 15 | fetsund
# Processing Record 26 of the Set 15 | coffs harbour
# Processing Record 27 of the Set 15 | bairiki
# Processing Record 28 of the Set 15 | barao de melgaco
# Processing Record 29 of the Set 15 | madison heights
# Processing Record 30 of the Set 15 | qasigiannguit
# Processing Record 31 of the Set 15 | lashio
# City not found. Skipping...
# Processing Record 32 of the Set 15 | qax
# City not found. Skipping...
# Processing Record 33 of the Set 15 | floro
# Processing Record 34 of the Set 15 | malwan
# Processing Record 35 of the Set 15 | hvammstangi
# Processing Record 36 of the Set 15 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 684

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)

# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Zhuhai      CN  22.2769  113.5678     69.71        63          20
# 1    La Ronge      CA  55.1001 -105.2842     -3.75        71          40
# 2  Port Blair      IN  11.6667   92.7500     82.44        65          40
# 3     Ushuaia      AR -54.8000  -68.3000     38.86        81          75
# 4      Dingle      PH  10.9995  122.6711     86.76        59          97
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        2.30    scattered clouds
# 2       10.36    scattered clouds
# 3        6.91       broken clouds
# 4       11.03     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
